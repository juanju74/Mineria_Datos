# %% [markdown]
# # Week 4: In-Class Exercise - Data Filtering & Selection
#
# ## Objective
# Practice filtering techniques using the same Education Statistics dataset you cleaned last week.
#
# ## Time: ~30 minutes
#
# ## What you'll practice:
# 1. **Single conditions** with comparison operators
# 2. **Combining conditions** with & (AND), | (OR), ~ (NOT)
# 3. **Convenience methods**: .isin(), .between(), .str.contains()
# 4. **Building real questions** from data
#
# ## Dataset
# Same Education Statistics from the Colombian Ministry of Education (MEN) you cleaned in Week 3.
#
# ---

# %% [markdown]
# ## Setup
# Run this cell to load libraries, load the dataset, and apply the quick clean from Week 3.

# %%
import pandas as pd
import numpy as np

# Load the Education Statistics dataset
df = pd.read_csv('../semana03/data/educacion_estadisticas.csv')

# Quick clean (applying what we learned in Week 3)
df['departamento'] = df['departamento'].str.upper().str.strip()
df['ano'] = df['ano'].fillna(0).astype(int)
df = df.drop_duplicates()
df = df.dropna(subset=['departamento'])

print(f"Dataset loaded and cleaned: {df.shape[0]} rows, {df.shape[1]} columns")
print(f"Years: {sorted(df['ano'].unique())}")
print(f"Departments: {df['departamento'].nunique()} unique")
df.head()
# Out:
# Dataset loaded and cleaned: 455 rows, 37 columns
# Years: [np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]
# Departments: 41 unique
#     ano  c_digo_departamento departamento poblacion_5_16  \
# 0  2023                   68    SANTANDER         405256
# 1  2024                   86     PUTUMAYO          81100
# 2  2016                   52       NARIÑO        394,574
# 3  2024                   50         META         221911
# 4  2020                    5    ANTIOQUIA        1151149
#
#    tasa_matriculacion_5_16  cobertura_neta  cobertura_neta_transicion  \
# 0                    95.80           95.64                      71.27
# 1                    80.03           80.01                      50.77
# 2                    71.10             NaN                      38.56
# 3                    90.34           90.29                      65.69
# 4                    93.59           93.43                      70.25
#
#    cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 0                    92.98                      83.40                 56.02
# 1                    78.12                      66.49                 38.12
# 2                    68.32                      56.56                 29.80
# 3                    89.17                      76.00                 48.10
# 4                    88.26                      83.38                 47.45
#
#    ...  reprobacion  reprobacion_transicion  reprobacion_primaria  \
# 0  ...         7.65                    2.95                 91.82
# 1  ...         6.07                    3.02                 90.68
# 2  ...         1.89                    0.04                 97.71
# 3  ...         6.84                    2.85                 91.18
# 4  ...          NaN                    0.79                 92.19
#
#    reprobacion_secundaria  reprobacion_media  repitencia  \
# 0                   12.95               6.92        7.99
# 1                   10.04               4.82        8.50
# 2                    3.07               1.92        2.64
# 3                   11.36               5.61        9.27
# 4                   11.46               7.12        6.48
#
#    repitencia_transicion  repitencia_primaria  repitencia_secundaria  \
# 0                   2.95                 7.32                  11.34
# 1                   3.02                 7.56                  12.33
# 2                   0.04                 2.36                   3.79
# 3                   2.85                 9.27                  12.53
# 4                   0.79                 5.92                   9.37
#
#    repitencia_media
# 0              4.07
# 1              4.57
# 2              1.34
# 3              3.49
# 4              3.17
#
# [5 rows x 37 columns]

# %% [markdown]
# ---
#
# ## Part 1: Single Conditions (8 minutes)
#
# Start with simple, one-condition filters using comparison operators.

# %% [markdown]
# ### Task 1.1: Filter by exact value
# Get all rows where the year (`ano`) is 2023.
#
# **Pattern:** `df[df['column'] == value]`
#
# Print how many rows you found.

# %%
# YOUR CODE HERE
# Step 1: Create the filter
# Step 2: Print the number of rows
# Step 3: Display the first few rows
# Step 1: Create the filter

df_2023 = df[df["ano"] == 2023]

# Step 2: Print the number of rows
print("Number of rows for 2023:", len(df_2023))

# Step 3: Display the first few rows
df_2023.head()
# Out:
# Number of rows for 2023: 33
#      ano  c_digo_departamento  departamento poblacion_5_16  \
# 0   2023                   68     SANTANDER         405256
# 7   2023                   73        TOLIMA         239730
# 15  2023                   94       GUAINÍA          16704
# 39  2023                   25  CUNDINAMARCA       sin dato
# 50  2023                   99       VICHADA          33816
#
#     tasa_matriculacion_5_16  cobertura_neta  cobertura_neta_transicion  \
# 0                     95.80           95.64                      71.27
# 7                     99.13           99.04                      76.38
# 15                    71.61           71.55                      62.35
# 39                    93.59           93.32                      62.91
# 50                    67.63           67.63                      51.88
#
#     cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 0                     92.98                      83.40                 56.02
# 7                     98.24                      83.94                 54.77
# 15                    70.20                      36.75                 10.67
# 39                    88.71                      85.25                 56.55
# 50                    75.84                      29.65                 11.24
#
#     ...  reprobacion  reprobacion_transicion  reprobacion_primaria  \
# 0   ...         7.65                    2.95                 91.82
# 7   ...         6.47                    4.21                 91.72
# 15  ...          NaN                    5.96                 80.41
# 39  ...         6.61                    4.09                 92.79
# 50  ...        14.59                    0.68                 75.32
#
#     reprobacion_secundaria  reprobacion_media  repitencia  \
# 0                    12.95               6.92        7.99
# 7                    10.13               5.28        8.61
# 15                   14.54               7.97       15.69
# 39                   11.05               5.40        8.29
# 50                   12.80               6.05       17.37
#
#     repitencia_transicion  repitencia_primaria  repitencia_secundaria  \
# 0                    2.95                 7.32                  11.34
# 7                    4.21                 9.19                  10.89
# 15                   5.96                19.12                  14.73
# 39                   4.09                 7.09                  12.23
# 50                   0.68                22.77                  11.74
#
#     repitencia_media
# 0               4.07
# 7               3.31
# 15              5.24
# 39              3.58
# 50              5.29
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Task 1.2: Filter with greater than
# Find all rows where the total dropout rate (`desercion`) is greater than 5%.
#
# **Question:** How many department-year combinations have a dropout rate above 5%?

# %%
df_desercion_5 = df[df["desercion"] > 5]

print("Rows with dropout > 5%:", len(df_desercion_5))

df_desercion_5.head()
# Out:
# Rows with dropout > 5%: 92
#      ano  c_digo_departamento departamento poblacion_5_16  \
# 1   2024                   86     PUTUMAYO          81100
# 9   2017                   94      GUAINÍA          11965
# 13  2020                   86     PUTUMAYO         80,810
# 15  2023                   94      GUAINÍA          16704
# 17  2011                   95     GUAVIARE          31133
#
#     tasa_matriculacion_5_16  cobertura_neta  cobertura_neta_transicion  \
# 1                     80.03           80.01                      50.77
# 9                     80.00           79.98                      59.60
# 13                    84.42           84.41                      50.72
# 15                    71.61           71.55                      62.35
# 17                    64.04           64.02                      32.16
#
#     cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 1                     78.12                      66.49                 38.12
# 9                     78.83                      36.62                  8.82
# 13                    80.58                      73.07                 39.50
# 15                    70.20                      36.75                 10.67
# 17                    65.42                      45.16                 20.08
#
#     ...  reprobacion  reprobacion_transicion  reprobacion_primaria  \
# 1   ...         6.07                    3.02                 90.68
# 9   ...        15.53                    7.92                 78.42
# 13  ...         5.78                    0.25                 90.59
# 15  ...          NaN                    5.96                 80.41
# 17  ...         0.18                    0.00                 91.73
#
#     reprobacion_secundaria  reprobacion_media  repitencia  \
# 1                    10.04               4.82        8.50
# 9                    19.29              13.37        3.13
# 13                    9.57               6.14        6.81
# 15                   14.54               7.97       15.69
# 17                    0.00               2.17        2.41
#
#     repitencia_transicion  repitencia_primaria  repitencia_secundaria  \
# 1                    3.02                 7.56                  12.33
# 9                    7.92                 3.35                   3.28
# 13                   0.25                 5.74                  10.17
# 15                   5.96                19.12                  14.73
# 17                   0.00                 2.08                   3.50
#
#     repitencia_media
# 1               4.57
# 9               0.38
# 13              4.66
# 15              5.24
# 17              1.86
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Task 1.3: Filter with less than
# Find all rows where net coverage (`cobertura_neta`) is less than 70%.
#
# **Question:** Which departments have the lowest coverage? Look at the `departamento` column in your result.

# %%
# YOUR CODE HERE
df_cobertura_70 = df[df["cobertura_neta"] < 70]

print("Rows with coverage < 70%:", len(df_cobertura_70))

df_cobertura_70[["departamento", "cobertura_neta"]].head()
# Out:
# Rows with coverage < 70%: 39
#    departamento  cobertura_neta
# 17     GUAVIARE           64.02
# 23      VICHADA           68.25
# 33        HUILA           -9.26
# 43       VAUPÉS           53.45
# 45     GUAVIARE           59.18

# %% [markdown]
# ---
#
# ## Part 2: Combining Conditions (8 minutes)
#
# Now combine multiple conditions using `&` (AND), `|` (OR), and `~` (NOT).
#
# **Remember:** Always wrap each condition in parentheses!

# %% [markdown]
# ### Task 2.1: AND condition
# Find rows where the year is 2023 AND the dropout rate is above 5%.
#
# **Pattern:** `df[(condition1) & (condition2)]`
#
# **Question:** Which departments had high dropout in 2023?

# %%
# YOUR CODE HERE
# Show: departamento, ano, desercion columns
df_2023_high_dropout = df[
    (df["ano"] == 2023) & (df["desercion"] > 5)
]

display(df_2023_high_dropout[["departamento", "ano", "desercion"]])
# Out:
#         departamento   ano  desercion
# 15           GUAINÍA  2023       6.03
# 112         AMAZONAS  2023       5.01
# 150          CAQUETÁ  2023       6.89
# 383  VALLE DEL CAUCA  2023       5.22
# 384        RISARALDA  2023       5.60
# 408         GUAVIARE  2023       5.62

# %% [markdown]
# ### Task 2.2: OR condition
# Find all rows from either Antioquia OR Valle del Cauca.
#
# **Pattern:** `df[(condition1) | (condition2)]`
#
# **Hint:** The department names should be uppercase (we cleaned them in setup).

# %%
# YOUR CODE HERE
df_selected = df[
    (df["departamento"] == "ANTIOQUIA") |(df["departamento"] == "VALLE DEL CAUCA")
]

display(df_selected)
# Out:
#       ano  c_digo_departamento     departamento poblacion_5_16  \
# 4    2020                    5        ANTIOQUIA        1151149
# 24   2012                    5        ANTIOQUIA        1278686
# 34   2011                    5        ANTIOQUIA        1288473
# 55   2024                    5        ANTIOQUIA        1128314
# 91   2012                   76  VALLE DEL CAUCA         894698
# 101  2018                    5        ANTIOQUIA        1147598
# 121  2023                    5        ANTIOQUIA      1,131,546
# 124  2015                    5        ANTIOQUIA        1262800
# 129  2013                    5        ANTIOQUIA        1272458
# 135  2011                   76  VALLE DEL CAUCA         906602
# 154  2015                   76  VALLE DEL CAUCA         875476
# 210  2021                   76  VALLE DEL CAUCA         839566
# 212  2024                   76  VALLE DEL CAUCA         836702
# 235  2019                   76  VALLE DEL CAUCA         854243
# 237  2017                    5        ANTIOQUIA        1270105
# 242  2013                   76  VALLE DEL CAUCA         887988
# 260  2014                   76  VALLE DEL CAUCA         880625
# 289  2020                   76  VALLE DEL CAUCA            NaN
# 326  2022                   76  VALLE DEL CAUCA        848,047
# 328  2017                   76  VALLE DEL CAUCA         873860
# 339  2018                   76  VALLE DEL CAUCA         861316
# 383  2023                   76  VALLE DEL CAUCA        842,813
# 421  2019                    5        ANTIOQUIA      1,149,985
# 437  2022                    5        ANTIOQUIA        1134099
# 465  2014                    5        ANTIOQUIA        1266533
# 469  2021                    5        ANTIOQUIA      1,149,861
# 475  2016                   76  VALLE DEL CAUCA         873706
#
#      tasa_matriculacion_5_16  cobertura_neta  cobertura_neta_transicion  \
# 4                      93.59           93.43                      70.25
# 24                     92.79           92.65                      73.20
# 34                     94.01           93.85                      70.28
# 55                     90.02           89.85                      68.83
# 91                     88.26           88.09                      60.32
# 101                    84.72           94.11                      67.98
# 121                    92.07           91.89                      72.25
# 124                    89.92           89.79                      61.07
# 129                    92.06           91.93                      67.61
# 135                    88.51           88.33                      56.25
# 154                    84.44           84.26                      50.96
# 210                    81.86           81.67                      55.21
# 212                    76.03           75.84                      54.51
# 235                    81.68           81.46                      55.95
# 237                    86.10           86.00                      56.58
# 242                    87.56           87.37                      58.92
# 260                    85.52           85.34                      53.64
# 289                    82.18             NaN                      57.87
# 326                    79.71           79.50                      59.59
# 328                    80.40           80.21                      49.95
# 339                    79.27           80.36                      53.98
# 383                    78.09           77.90                      58.61
# 421                    94.00           93.83                      67.86
# 437                    93.50           93.32                      73.12
# 465                    90.97             NaN                      64.15
# 469                    92.62           92.45                      69.22
# 475                    81.40           81.23                      47.12
#
#      cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 4                      88.26                      83.38                 47.45
# 24                     92.65                      74.84                 43.50
# 34                     94.12                      75.68                 44.37
# 55                     87.32                      77.04                 52.81
# 91                     86.16                      71.21                 40.62
# 101                      NaN                      81.29                 43.83
# 121                    88.03                      79.26                 53.34
# 124                    89.02                      74.17                 42.61
# 129                    91.53                      75.66                 42.71
# 135                    86.83                      72.17                 42.06
# 154                    82.63                      69.59                 39.64
# 210                    76.54                      72.48                 47.88
# 212                    73.57                      65.01                 45.72
# 235                    76.71                      72.69                 41.95
# 237                    83.30                      73.93                 42.85
# 242                    84.98                      71.27                 40.61
# 260                    83.48                      70.81                 39.12
# 289                    77.11                      73.15                 44.44
# 326                    75.32                      68.57                 47.39
# 328                    76.38                      71.03                 40.74
# 339                    76.19                      71.45                 40.20
# 383                    74.78                      66.48                 46.35
# 421                    90.24                      82.60                 45.04
# 437                    88.54                      81.83                 52.35
# 465                    90.68                      75.13                 41.79
# 469                    87.05                      82.80                 49.85
# 475                    78.38                      69.91                 41.43
#
#      ...  reprobacion  reprobacion_transicion  reprobacion_primaria  \
# 4    ...          NaN                    0.79                 92.19
# 24   ...         3.95                    0.20                 93.05
# 34   ...         2.06                    0.07                 94.56
# 55   ...         7.27                    1.90                 91.58
# 91   ...         3.29                    0.20                 93.91
# 101  ...         6.91                    0.19                 91.00
# 121  ...         8.47                    1.94                 89.38
# 124  ...         6.84                    0.20                 91.59
# 129  ...         4.84                    0.12                 93.02
# 135  ...         5.07                    0.58                 92.95
# 154  ...         6.18                    0.69                 93.14
# 210  ...         8.31                    1.04                 88.67
# 212  ...         7.54                    4.89                 90.12
# 235  ...         7.25                    0.71                 91.13
# 237  ...         7.16                    0.19                 90.80
# 242  ...         3.39                    0.25                 94.83
# 260  ...         2.24                    0.18                 96.62
# 289  ...         6.86                    1.88                 92.43
# 326  ...         8.01                    0.79                 88.78
# 328  ...         6.70                    0.84                 91.59
# 339  ...         7.52                    0.50                 91.63
# 383  ...         8.43                    5.19                 88.92
# 421  ...         7.59                    0.18                 90.73
# 437  ...         8.17                    0.25                 89.52
# 465  ...         2.59                    0.07                 96.35
# 469  ...         7.66                    0.30                 89.26
# 475  ...         6.94                    0.64                 91.33
#
#      reprobacion_secundaria  reprobacion_media  repitencia  \
# 4                     11.46               7.12        6.48
# 24                     5.55               4.02        1.93
# 34                     2.54               2.96        4.25
# 55                    11.75               5.80        9.26
# 91                     5.28               3.33        1.64
# 101                   10.05               5.41        3.13
# 121                   13.34               6.49        9.69
# 124                   10.56               5.64        2.83
# 129                    6.96               5.17        1.57
# 135                    7.90               6.37        2.30
# 154                    9.70               4.99        0.92
# 210                   11.48               7.61        4.76
# 212                   12.01               5.86        8.84
# 235                   10.80               5.81        1.17
# 237                   10.64               5.66        6.52
# 242                    5.13               3.52        1.30
# 260                    3.61               2.14        0.82
# 289                    9.92               6.50        5.72
# 326                   12.15               6.48        6.33
# 328                   10.03               4.78        1.45
# 339                   11.36               6.34        1.10
# 383                   12.93               7.00        9.08
# 421                   11.56               5.68        3.19
# 437                   12.49               6.35        6.49
# 465                    4.20               3.09        2.09
# 469                   10.65               6.93        5.84
# 475                   10.69               5.71        1.29
#
#      repitencia_transicion  repitencia_primaria  repitencia_secundaria  \
# 4                     0.79                 5.92                   9.37
# 24                    0.20                 1.67                   2.95
# 34                    0.07                 4.56                   5.27
# 55                    1.90                 8.78                  13.31
# 91                    0.20                 1.39                   2.40
# 101                   0.19                 3.14                   4.22
# 121                   1.94                 9.54                  13.52
# 124                   0.20                 2.26                   4.55
# 129                   0.12                 1.41                   2.27
# 135                   0.58                 2.09                   3.22
# 154                   0.69                 0.72                   1.44
# 210                   1.04                 4.06                   6.92
# 212                   4.89                 8.34                  11.98
# 235                   0.71                 1.06                   1.64
# 237                   0.19                 6.31                   8.94
# 242                   0.25                 1.09                   1.90
# 260                   0.18                 0.81                   1.06
# 289                   1.88                 5.05                   8.31
# 326                   0.79                 6.22                   8.55
# 328                   0.84                 1.35                   1.93
# 339                   0.50                 1.06                   1.44
# 383                   5.19                 9.01                  11.93
# 421                   0.18                 2.92                   4.65
# 437                   0.25                 6.58                   8.78
# 465                   0.07                 1.61                   3.35
# 469                   0.30                 5.07                   8.68
# 475                   0.64                 1.24                   1.70
#
#      repitencia_media
# 4                3.17
# 24               1.10
# 34               1.68
# 55               4.19
# 91               1.01
# 101              1.29
# 121              4.23
# 124              1.95
# 129              1.12
# 135              1.09
# 154              0.60
# 210              2.80
# 212              4.38
# 235              0.61
# 237              2.97
# 242              0.86
# 260              0.52
# 289              2.85
# 326              3.83
# 328              0.78
# 339              0.59
# 383              4.03
# 421              1.37
# 437              3.34
# 465              1.84
# 469              3.02
# 475              0.54
#
# [27 rows x 37 columns]

# %% [markdown]
# ### Task 2.3: NOT condition
# Get all rows EXCEPT those from the "NACIONAL" department (the national aggregate).
#
# **Two ways to do this:**
# - `df[df['departamento'] != 'NACIONAL']`
# - `df[~(df['departamento'] == 'NACIONAL')]`
#
# Try both and verify you get the same number of rows.

# %%
# YOUR CODE HERE
# Method 1: using !=
df_not_nacional_1 = df[df["departamento"] != "NACIONAL"]
# Method 2: using ~
df_not_nacional_2 = df[~(df["departamento"] == "NACIONAL")]
# Compare the row counts
print(df_not_nacional_1.shape[0])
print(df_not_nacional_2.shape[0])
# Out:
# 455
# 455

# %% [markdown]
# ---
#
# ## Part 3: Convenience Methods (7 minutes)
#
# Use `.isin()`, `.between()`, and `.str.contains()` to write cleaner filters.

# %% [markdown]
# ### Task 3.1: .isin() - Match a list
# Find all rows from the following departments: ANTIOQUIA, BOGOTA D.C., VALLE DEL CAUCA, CUNDINAMARCA.
#
# **Pattern:** `df[df['column'].isin([list_of_values])]`

# %%
# YOUR CODE HERE
departments_list = [
    "ANTIOQUIA",
    "BOGOTA D.C.",
    "VALLE DEL CAUCA",
    "CUNDINAMARCA"
]

df_selected_departments = df[
    df["departamento"].isin(departments_list)
]

display(df_selected_departments)
# Out:
#       ano  c_digo_departamento     departamento poblacion_5_16  \
# 4    2020                    5        ANTIOQUIA        1151149
# 11   2016                   25     CUNDINAMARCA         577612
# 24   2012                    5        ANTIOQUIA        1278686
# 34   2011                    5        ANTIOQUIA        1288473
# 39   2023                   25     CUNDINAMARCA       sin dato
# 55   2024                    5        ANTIOQUIA        1128314
# 61   2020                   25     CUNDINAMARCA         592264
# 72   2013                   25     CUNDINAMARCA         572012
# 91   2012                   76  VALLE DEL CAUCA         894698
# 101  2018                    5        ANTIOQUIA        1147598
# 121  2023                    5        ANTIOQUIA      1,131,546
# 124  2015                    5        ANTIOQUIA        1262800
# 129  2013                    5        ANTIOQUIA        1272458
# 135  2011                   76  VALLE DEL CAUCA         906602
# 154  2015                   76  VALLE DEL CAUCA         875476
# 176  2017                   25     CUNDINAMARCA        579,364
# 181  2014                   25     CUNDINAMARCA         573948
# 210  2021                   76  VALLE DEL CAUCA         839566
# 212  2024                   76  VALLE DEL CAUCA         836702
# 226  2019                   25     CUNDINAMARCA            NaN
# 227  2011                   25     CUNDINAMARCA            NaN
# 235  2019                   76  VALLE DEL CAUCA         854243
# 237  2017                    5        ANTIOQUIA        1270105
# 242  2013                   76  VALLE DEL CAUCA         887988
# 260  2014                   76  VALLE DEL CAUCA         880625
# 266  2021                   25     CUNDINAMARCA         610367
# 281  2022                   25     CUNDINAMARCA       sin dato
# 289  2020                   76  VALLE DEL CAUCA            NaN
# 325  2015                   25     CUNDINAMARCA         576429
# 326  2022                   76  VALLE DEL CAUCA        848,047
# 328  2017                   76  VALLE DEL CAUCA         873860
# 339  2018                   76  VALLE DEL CAUCA         861316
# 383  2023                   76  VALLE DEL CAUCA        842,813
# 399  2012                   25     CUNDINAMARCA         571082
# 421  2019                    5        ANTIOQUIA      1,149,985
# 422  2018                   25     CUNDINAMARCA         547875
# 437  2022                    5        ANTIOQUIA        1134099
# 465  2014                    5        ANTIOQUIA        1266533
# 469  2021                    5        ANTIOQUIA      1,149,861
# 475  2016                   76  VALLE DEL CAUCA         873706
#
#      tasa_matriculacion_5_16  cobertura_neta  cobertura_neta_transicion  \
# 4                      93.59           93.43                      70.25
# 11                     91.20           90.90                      56.31
# 24                     92.79           92.65                      73.20
# 34                     94.01           93.85                      70.28
# 39                     93.59           93.32                      62.91
# 55                     90.02           89.85                      68.83
# 61                     93.68           93.42                      64.47
# 72                     90.49           90.28                      61.00
# 91                     88.26           88.09                      60.32
# 101                    84.72           94.11                      67.98
# 121                    92.07           91.89                      72.25
# 124                    89.92           89.79                      61.07
# 129                    92.06           91.93                      67.61
# 135                    88.51           88.33                      56.25
# 154                    84.44           84.26                      50.96
# 176                    91.80           91.56                      57.22
# 181                    89.99           89.79                      58.96
# 210                    81.86           81.67                      55.21
# 212                    76.03           75.84                      54.51
# 226                    96.14           95.86                      65.93
# 227                    92.13           91.93                      67.19
# 235                    81.68           81.46                      55.95
# 237                    86.10           86.00                      56.58
# 242                    87.56           87.37                      58.92
# 260                    85.52           85.34                      53.64
# 266                    90.84           90.58                      60.68
# 281                    96.46           96.16                      67.26
# 289                    82.18             NaN                      57.87
# 325                    90.72           90.47                      55.93
# 326                    79.71           79.50                      59.59
# 328                    80.40           80.21                      49.95
# 339                    79.27           80.36                      53.98
# 383                    78.09           77.90                      58.61
# 399                    91.17           90.97                      63.61
# 421                    94.00           93.83                      67.86
# 422                    92.49           97.91                      67.00
# 437                    93.50           93.32                      73.12
# 465                    90.97             NaN                      64.15
# 469                    92.62           92.45                      69.22
# 475                    81.40           81.23                      47.12
#
#      cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 4                      88.26                      83.38                 47.45
# 11                     88.25                      80.47                 50.92
# 24                     92.65                      74.84                 43.50
# 34                     94.12                      75.68                 44.37
# 39                     88.71                      85.25                 56.55
# 55                     87.32                      77.04                 52.81
# 61                     90.32                      86.08                 50.35
# 72                     85.47                      82.08                 47.98
# 91                     86.16                      71.21                 40.62
# 101                      NaN                      81.29                 43.83
# 121                    88.03                      79.26                 53.34
# 124                    89.02                      74.17                 42.61
# 129                    91.53                      75.66                 42.71
# 135                    86.83                      72.17                 42.06
# 154                    82.63                      69.59                 39.64
# 176                    89.27                      81.65                 51.57
# 181                      NaN                      81.31                 48.48
# 210                    76.54                      72.48                 47.88
# 212                    73.57                      65.01                 45.72
# 226                    94.63                      85.96                 49.70
# 227                    88.12                      81.38                 47.57
# 235                    76.71                      72.69                 41.95
# 237                    83.30                      73.93                 42.85
# 242                    84.98                      71.27                 40.61
# 260                    83.48                      70.81                 39.12
# 266                    85.96                      84.79                 50.40
# 281                    91.19                      88.69                 54.67
# 289                    77.11                      73.15                 44.44
# 325                      NaN                      80.91                 50.50
# 326                    75.32                      68.57                 47.39
# 328                    76.38                      71.03                 40.74
# 339                    76.19                      71.45                 40.20
# 383                    74.78                      66.48                 46.35
# 399                    87.82                      81.53                 47.27
# 421                    90.24                      82.60                 45.04
# 422                    98.58                      86.40                 50.34
# 437                    88.54                      81.83                 52.35
# 465                    90.68                      75.13                 41.79
# 469                    87.05                      82.80                 49.85
# 475                    78.38                      69.91                 41.43
#
#      ...  reprobacion  reprobacion_transicion  reprobacion_primaria  \
# 4    ...          NaN                    0.79                 92.19
# 11   ...         3.05                    0.54                 95.30
# 24   ...         3.95                    0.20                 93.05
# 34   ...         2.06                    0.07                 94.56
# 39   ...         6.61                    4.09                 92.79
# 55   ...         7.27                    1.90                 91.58
# 61   ...         6.63                    1.61                 93.77
# 72   ...         1.12                    0.03                 96.84
# 91   ...         3.29                    0.20                 93.91
# 101  ...         6.91                    0.19                 91.00
# 121  ...         8.47                    1.94                 89.38
# 124  ...         6.84                    0.20                 91.59
# 129  ...         4.84                    0.12                 93.02
# 135  ...         5.07                    0.58                 92.95
# 154  ...         6.18                    0.69                 93.14
# 176  ...          NaN                    0.54                 95.79
# 181  ...         0.69                    0.01                 97.80
# 210  ...         8.31                    1.04                 88.67
# 212  ...         7.54                    4.89                 90.12
# 226  ...         5.30                    0.67                 94.29
# 227  ...         0.89                    0.04                 96.62
# 235  ...         7.25                    0.71                 91.13
# 237  ...         7.16                    0.19                 90.80
# 242  ...         3.39                    0.25                 94.83
# 260  ...         2.24                    0.18                 96.62
# 266  ...         6.59                    1.03                 92.02
# 281  ...         6.12                    1.21                 92.63
# 289  ...         6.86                    1.88                 92.43
# 325  ...          NaN                    0.43                 95.57
# 326  ...         8.01                    0.79                 88.78
# 328  ...         6.70                    0.84                 91.59
# 339  ...         7.52                    0.50                 91.63
# 383  ...         8.43                    5.19                 88.92
# 399  ...         1.22                    0.06                 97.25
# 421  ...         7.59                    0.18                 90.73
# 422  ...         5.00                    0.74                 94.56
# 437  ...         8.17                    0.25                 89.52
# 465  ...         2.59                    0.07                 96.35
# 469  ...         7.66                    0.30                 89.26
# 475  ...         6.94                    0.64                 91.33
#
#      reprobacion_secundaria  reprobacion_media  repitencia  \
# 4                     11.46               7.12        6.48
# 11                     4.97               2.56        2.40
# 24                     5.55               4.02        1.93
# 34                     2.54               2.96        4.25
# 39                    11.05               5.40        8.29
# 55                    11.75               5.80        9.26
# 61                    10.51               7.26        5.29
# 72                     1.93               1.41        1.90
# 91                     5.28               3.33        1.64
# 101                   10.05               5.41        3.13
# 121                   13.34               6.49        9.69
# 124                   10.56               5.64        2.83
# 129                    6.96               5.17        1.57
# 135                    7.90               6.37        2.30
# 154                    9.70               4.99        0.92
# 176                    5.22               3.13        2.43
# 181                    1.15               1.25        1.73
# 210                   11.48               7.61        4.76
# 212                   12.01               5.86        8.84
# 226                    8.57               4.59        1.74
# 227                    1.26               1.93        2.70
# 235                   10.80               5.81        1.17
# 237                   10.64               5.66        6.52
# 242                    5.13               3.52        1.30
# 260                    3.61               2.14        0.82
# 266                   10.10               7.20        5.20
# 281                   10.00               4.96        6.81
# 289                    9.92               6.50        5.72
# 325                    5.80               3.30        2.14
# 326                   12.15               6.48        6.33
# 328                   10.03               4.78        1.45
# 339                   11.36               6.34        1.10
# 383                   12.93               7.00        9.08
# 399                    1.97               1.97        2.02
# 421                   11.56               5.68        3.19
# 422                    7.80               5.03        2.11
# 437                   12.49               6.35        6.49
# 465                    4.20               3.09        2.09
# 469                   10.65               6.93        5.84
# 475                   10.69               5.71        1.29
#
#      repitencia_transicion  repitencia_primaria  repitencia_secundaria  \
# 4                     0.79                 5.92                   9.37
# 11                    0.54                 1.86                   3.71
# 24                    0.20                 1.67                   2.95
# 34                    0.07                 4.56                   5.27
# 39                    4.09                 7.09                  12.23
# 55                    1.90                 8.78                  13.31
# 61                    1.61                 4.22                   8.09
# 72                    0.03                 1.39                   2.95
# 91                    0.20                 1.39                   2.40
# 101                   0.19                 3.14                   4.22
# 121                   1.94                 9.54                  13.52
# 124                   0.20                 2.26                   4.55
# 129                   0.12                 1.41                   2.27
# 135                   0.58                 2.09                   3.22
# 154                   0.69                 0.72                   1.44
# 176                   0.54                 1.92                   3.67
# 181                   0.01                 1.23                   2.73
# 210                   1.04                 4.06                   6.92
# 212                   4.89                 8.34                  11.98
# 226                   0.67                 1.33                   2.76
# 227                   0.04                 1.99                   4.18
# 235                   0.71                 1.06                   1.64
# 237                   0.19                 6.31                   8.94
# 242                   0.25                 1.09                   1.90
# 260                   0.18                 0.81                   1.06
# 266                   1.03                 3.59                   8.39
# 281                   1.21                 5.58                  10.32
# 289                   1.88                 5.05                   8.31
# 325                   0.43                 1.67                   3.26
# 326                   0.79                 6.22                   8.55
# 328                   0.84                 1.35                   1.93
# 339                   0.50                 1.06                   1.44
# 383                   5.19                 9.01                  11.93
# 399                   0.06                 1.53                   3.20
# 421                   0.18                 2.92                   4.65
# 422                   0.74                 1.60                   3.34
# 437                   0.25                 6.58                   8.78
# 465                   0.07                 1.61                   3.35
# 469                   0.30                 5.07                   8.68
# 475                   0.64                 1.24                   1.70
#
#      repitencia_media
# 4                3.17
# 11               1.46
# 24               1.10
# 34               1.68
# 39               3.58
# 55               4.19
# 61               3.04
# 72               1.52
# 91               1.01
# 101              1.29
# 121              4.23
# 124              1.95
# 129              1.12
# 135              1.09
# 154              0.60
# 176              1.54
# 181              1.43
# 210              2.80
# 212              4.38
# 226              0.82
# 227              1.78
# 235              0.61
# 237              2.97
# 242              0.86
# 260              0.52
# 266              3.37
# 281              4.01
# 289              2.85
# 325              1.44
# 326              3.83
# 328              0.78
# 339              0.59
# 383              4.03
# 399              1.28
# 421              1.37
# 422              1.14
# 437              3.34
# 465              1.84
# 469              3.02
# 475              0.54
#
# [40 rows x 37 columns]

# %% [markdown]
# ### Task 3.2: .between() - Numeric range
# Find all rows where the approval rate (`aprobacion`) is between 90 and 100 (inclusive).
#
# **Pattern:** `df[df['column'].between(low, high)]`

# %%
# YOUR CODE HERE
df_high_approval = df[
    df["aprobacion"].between(90, 100)
]

display(df_high_approval)
# Out:
#       ano  c_digo_departamento departamento poblacion_5_16  \
# 2    2016                   52       NARIÑO        394,574
# 5    2015                   52       NARIÑO         396138
# 6    2022                   52       NARIÑO         307217
# 8    2011                   47    MAGDALENA         333793
# 10   2011                   23      CÓRDOBA         405431
# ..    ...                  ...          ...            ...
# 471  2018                   18      CAQUETÁ          98639
# 472  2014                   73       TOLIMA         313709
# 474  2011                   68    SANTANDER         434034
# 477  2014                   19        CAUCA       sin dato
# 478  2019                   18      CAQUETÁ            NaN
#
#      tasa_matriculacion_5_16  cobertura_neta  cobertura_neta_transicion  \
# 2                      71.10             NaN                      38.56
# 5                      73.53             NaN                      39.88
# 6                      80.63             NaN                      59.47
# 8                      94.47           94.32                      55.40
# 10                     94.53           94.46                      67.18
# ..                       ...             ...                        ...
# 471                    73.14             NaN                      59.17
# 472                    86.36           86.30                      51.27
# 474                    92.49           92.40                      69.70
# 477                    84.60           84.58                      45.54
# 478                    90.52           90.49                      57.80
#
#      cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 2                      68.32                      56.56                 29.80
# 5                      71.43                      56.46                 29.95
# 6                        NaN                      66.77                 41.78
# 8                      90.90                      66.53                 37.55
# 10                     93.22                      68.79                 37.16
# ..                       ...                        ...                   ...
# 471                    90.89                      69.46                 32.22
# 472                    84.15                      72.77                 40.72
# 474                    92.88                      77.28                 48.10
# 477                    86.00                      64.65                 31.39
# 478                    89.20                      68.56                 33.58
#
#      ...  reprobacion  reprobacion_transicion  reprobacion_primaria  \
# 2    ...         1.89                    0.04                 97.71
# 5    ...         2.35                    0.03                 97.47
# 6    ...         5.14                    1.41                 93.08
# 8    ...         1.39                    0.42                 95.12
# 10   ...         1.12                    0.22                 95.13
# ..   ...          ...                     ...                   ...
# 471  ...         1.88                    0.42                 93.80
# 472  ...         5.53                    0.27                 91.55
# 474  ...          NaN                    0.34                 96.11
# 477  ...         0.12                    0.00                 96.17
# 478  ...         2.05                    0.41                 93.40
#
#      reprobacion_secundaria  reprobacion_media  repitencia  \
# 2                      3.07               1.92        2.64
# 5                      3.39               3.28        1.35
# 6                      6.93               4.28        8.07
# 8                      1.41               2.08        1.52
# 10                     1.37               2.71        4.07
# ..                      ...                ...         ...
# 471                    2.57               2.43        2.52
# 472                    8.58               4.93        0.92
# 474                    3.48               2.98        2.92
# 477                    0.01               0.97        1.20
# 478                    2.51               2.53        2.60
#
#      repitencia_transicion  repitencia_primaria  repitencia_secundaria  \
# 2                     0.04                 2.36                   3.79
# 5                     0.03                 1.04                   2.27
# 6                     1.41                 9.03                  10.00
# 8                     0.42                 1.44                   1.99
# 10                    0.22                 4.18                   4.53
# ..                     ...                  ...                    ...
# 471                   0.42                 2.51                   3.36
# 472                   0.27                 0.82                   1.32
# 474                   0.34                 2.30                   4.48
# 477                   0.00                 1.05                   1.78
# 478                   0.41                 2.70                   3.28
#
#      repitencia_media
# 2                1.34
# 5                0.95
# 6                3.49
# 8                0.65
# 10               2.43
# ..                ...
# 471              1.37
# 472              0.65
# 474              1.59
# 477              1.01
# 478              1.12
#
# [199 rows x 37 columns]

# %% [markdown]
# ### Task 3.3: .str.contains() - Text pattern
# Find all rows where the department name contains "SANTANDER".
#
# **Pattern:** `df[df['column'].str.contains('text', na=False)]`
#
# **Question:** Which departments match? (Hint: there should be more than one.)

# %%
# YOUR CODE HERE
# Print the unique department names in your result
df_santander = df[
    df["departamento"].str.contains("SANTANDER", na=False)
]

display(df_santander)
print("Matching departments:")
print(df_santander["departamento"].unique())
# Out:
#       ano  c_digo_departamento        departamento poblacion_5_16  \
# 0    2023                   68           SANTANDER         405256
# 22   2019                   54  NORTE DE SANTANDER         318252
# 52   2016                   68           SANTANDER         402820
# 64   2013                   68           SANTANDER        419,596
# 92   2017                   68           SANTANDER        398,621
# 114  2020                   68           SANTANDER         408876
# 127  2011                   54  NORTE DE SANTANDER         324219
# 140  2014                   54  NORTE DE SANTANDER            NaN
# 161  2024                   68           SANTANDER         404490
# 165  2020                   54  NORTE DE SANTANDER         325981
# 184  2018                   54  NORTE DE SANTANDER         307526
# 185  2015                   68           SANTANDER            NaN
# 188  2013                   54  NORTE DE SANTANDER            NaN
# 192  2021                   54  NORTE DE SANTANDER         328034
# 197  2014                   68           SANTANDER        413,227
# 236  2019                   68           SANTANDER         405798
# 245  2022                   54  NORTE DE SANTANDER         328869
# 268  2022                   68           SANTANDER         405521
# 351  2017                   54  NORTE DE SANTANDER       sin dato
# 373  2024                   54  NORTE DE SANTANDER         330046
# 391  2018                   68           SANTANDER         401463
# 395  2021                   68           SANTANDER        409,198
# 405  2012                   68           SANTANDER         425904
# 438  2012                   54  NORTE DE SANTANDER         322304
# 457  2023                   54  NORTE DE SANTANDER         329874
# 461  2015                   54  NORTE DE SANTANDER         310611
# 474  2011                   68           SANTANDER         434034
#
#      tasa_matriculacion_5_16  cobertura_neta  cobertura_neta_transicion  \
# 0                      95.80           95.64                      71.27
# 22                     92.25           92.18                      64.42
# 52                     95.20           95.00                      59.67
# 64                     93.40           93.28                      60.45
# 92                     96.50           96.33                      63.75
# 114                    95.97           95.83                      68.01
# 127                    89.04           88.96                      68.90
# 140                    87.20           87.15                      57.87
# 161                    93.06             NaN                      65.07
# 165                    90.24           90.16                      66.90
# 184                    93.58           91.62                      65.88
# 185                    94.50           94.37                      59.90
# 188                    86.42           86.37                      61.14
# 192                    92.06           92.00                      65.58
# 197                    93.63           93.52                      57.10
# 236                    96.38           96.20                      67.64
# 245                    91.88           91.81                      69.99
# 268                    96.67           96.49                      73.28
# 351                    90.40           90.30                      61.33
# 373                    87.90           87.85                      65.52
# 391                    97.79           96.06                      67.51
# 395                    96.05           95.89                      67.85
# 405                    92.21           92.11                      70.17
# 438                    86.00           85.93                      71.79
# 457                    91.17           91.11                      68.85
# 461                    85.89           85.84                      58.03
# 474                    92.49           92.40                      69.70
#
#      cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 0                      92.98                      83.40                 56.02
# 22                       NaN                      76.09                 41.87
# 52                     94.75                      83.00                 50.45
# 64                     92.92                      80.27                 48.09
# 92                     95.04                      85.29                 51.23
# 114                    93.45                      85.52                 51.23
# 127                    91.01                      66.38                 39.03
# 140                    89.64                      68.40                 36.99
# 161                      NaN                      82.32                 54.99
# 165                    89.00                      76.87                 41.20
# 184                      NaN                      74.50                 40.56
# 185                    94.34                      82.45                 47.84
# 188                    88.74                      66.27                 37.86
# 192                    89.54                      79.23                 44.63
# 197                    93.33                      81.72                 47.00
# 236                    94.58                      84.70                 49.96
# 245                      NaN                      76.87                 46.66
# 268                    93.72                      84.59                 53.91
# 351                      NaN                      73.65                 39.83
# 373                    86.65                      73.33                 47.94
# 391                    94.88                      83.83                 49.63
# 395                    93.03                      86.89                 53.30
# 405                      NaN                      77.82                 46.84
# 438                      NaN                      64.30                 35.87
# 457                    88.68                      75.55                 49.14
# 461                    89.27                      68.70                 36.24
# 474                    92.88                      77.28                 48.10
#
#      ...  reprobacion  reprobacion_transicion  reprobacion_primaria  \
# 0    ...         7.65                    2.95                 91.82
# 22   ...         6.19                    0.85                 92.43
# 52   ...         6.14                    0.52                 92.98
# 64   ...          NaN                    0.47                 95.30
# 92   ...          NaN                    0.46                 93.96
# 114  ...         7.10                    2.84                 93.97
# 127  ...         0.65                    0.06                 94.41
# 140  ...          NaN                    0.09                 96.28
# 161  ...         6.88                    2.62                 92.49
# 165  ...         7.24                    2.67                 89.74
# 184  ...         5.50                    0.40                 92.65
# 185  ...         4.90                    0.81                 94.70
# 188  ...         1.05                    0.14                 96.15
# 192  ...         8.33                    1.40                 89.53
# 197  ...         1.73                    0.49                 96.59
# 236  ...         7.47                    0.46                 93.03
# 245  ...         7.95                    0.73                 88.89
# 268  ...         7.58                    0.49                 90.32
# 351  ...         4.54                    1.17                 94.38
# 373  ...         7.38                    2.70                 90.55
# 391  ...         7.34                    0.45                 93.15
# 395  ...         8.51                    0.77                 90.95
# 405  ...         2.68                    0.32                 94.58
# 438  ...         1.52                    0.31                 94.52
# 457  ...         8.49                    2.56                 89.26
# 461  ...         1.59                    0.15                 96.86
# 474  ...          NaN                    0.34                 96.11
#
#      reprobacion_secundaria  reprobacion_media  repitencia  \
# 0                     12.95               6.92        7.99
# 22                     9.56               6.46        1.37
# 52                    10.22               6.15        2.48
# 64                     5.58               4.41        2.04
# 92                     9.87               5.88        2.41
# 114                   11.15               6.84        6.26
# 127                    0.76               1.64        2.19
# 140                    1.02               1.06        1.64
# 161                   12.00               6.04        7.60
# 165                    9.48               6.11        5.51
# 184                    8.60               6.34        1.41
# 185                    8.18               5.13        1.62
# 188                    1.63               1.50        1.72
# 192                   12.07               8.50        3.90
# 197                    2.80               2.27        1.76
# 236                   12.42               7.26        1.91
# 245                   11.55               7.54        6.03
# 268                   12.17               7.10        6.43
# 351                    7.58               5.02        1.24
# 373                   12.11               6.61        8.39
# 391                   12.29               7.35        1.73
# 395                   13.68               8.85        4.47
# 405                    4.44               3.23        2.53
# 438                    2.45               2.21        2.00
# 457                   13.56               7.94        8.19
# 461                    2.55               2.11        1.31
# 474                    3.48               2.98        2.92
#
#      repitencia_transicion  repitencia_primaria  repitencia_secundaria  \
# 0                     2.95                 7.32                  11.34
# 22                    0.85                 1.34                   1.83
# 52                    0.52                 1.96                   3.90
# 64                    0.47                 1.48                   3.29
# 92                    0.46                 1.92                   3.75
# 114                   2.84                 4.70                   9.96
# 127                   0.06                 1.70                   3.46
# 140                   0.09                 1.21                   2.71
# 161                   2.62                 6.16                  11.57
# 165                   2.67                 4.57                   8.25
# 184                   0.40                 1.35                   1.94
# 185                   0.81                 1.12                   2.64
# 188                   0.14                 1.30                   2.67
# 192                   1.40                 3.10                   5.92
# 197                   0.49                 1.36                   2.80
# 236                   0.46                 1.49                   2.96
# 245                   0.73                 5.71                   8.54
# 268                   0.49                 4.91                  10.43
# 351                   1.17                 1.20                   1.70
# 373                   2.70                 7.85                  11.77
# 391                   0.45                 1.43                   2.71
# 395                   0.77                 3.05                   7.45
# 405                   0.32                 1.75                   4.18
# 438                   0.31                 1.51                   3.15
# 457                   2.56                 8.84                  10.09
# 461                   0.15                 1.08                   2.00
# 474                   0.34                 2.30                   4.48
#
#      repitencia_media
# 0                4.07
# 22               0.77
# 52               1.27
# 64               1.35
# 92               1.34
# 114              4.02
# 127              1.56
# 140              1.40
# 161              4.20
# 165              4.13
# 184              0.81
# 185              1.31
# 188              1.56
# 192              2.79
# 197              1.36
# 236              1.17
# 245              3.55
# 268              4.02
# 351              0.54
# 373              4.71
# 391              0.71
# 395              2.91
# 405              1.58
# 438              1.55
# 457              4.09
# 461              0.85
# 474              1.59
#
# [27 rows x 37 columns]
# Matching departments:
# <StringArray>
# ['SANTANDER', 'NORTE DE SANTANDER']
# Length: 2, dtype: str

# %% [markdown]
# ---
#
# ## Part 4: Real Questions (5 minutes)
#
# Use everything you've learned to answer these questions about the data.

# %% [markdown]
# ### Task 4.1: Complex filter
# Find departments in 2023 where:
# - Net coverage is above 80% AND
# - Dropout rate is below 3%
#
# These are the "high performing" departments. Show the department name, coverage, and dropout columns.

# %%
# YOUR CODE HERE
df_high_performing = df[
    (df["ano"] == 2023) &
    (df["cobertura_neta"] > 80) &
    (df["desercion"] < 3)
]

display(df_high_performing[
    ["departamento", "cobertura_neta", "desercion"]
])
# Out:
#      departamento  cobertura_neta  desercion
# 51      ATLÁNTICO           93.63       2.34
# 73   BOGOTÁ, D.C.           92.40       2.82
# 276         CHOCÓ           84.91       2.32
# 340        BOYACÁ           91.92       2.43

# %% [markdown]
# ### Task 4.2: Try .query()
# Rewrite the filter from Task 4.1 using `.query()` instead of boolean indexing.
#
# **Pattern:** `df.query('condition1 and condition2')`
#
# Verify you get the same number of rows.

# %%
# YOUR CODE HERE
df_high_performing_query = df.query(
    "ano == 2023 and cobertura_neta > 80 and desercion < 3"
)

display(df_high_performing_query)

print("Rows with boolean indexing:",
      df_high_performing.shape[0])

print("Rows with query():",
      df_high_performing_query.shape[0])
# Out:
#       ano  c_digo_departamento  departamento poblacion_5_16  \
# 51   2023                    8     ATLÁNTICO        545,813
# 73   2023                   11  BOGOTÁ, D.C.       sin dato
# 276  2023                   27         CHOCÓ        147,698
# 340  2023                   15        BOYACÁ         233865
#
#      tasa_matriculacion_5_16  cobertura_neta  cobertura_neta_transicion  \
# 51                     94.06           93.63                      65.86
# 73                     92.90           92.40                      61.43
# 276                    84.91           84.91                      55.21
# 340                    91.98           91.92                      71.42
#
#      cobertura_neta_primaria  cobertura_neta_secundaria  cobertura_neta_media  \
# 51                     89.59                      79.14                 55.30
# 73                     86.97                      86.48                 64.42
# 276                    86.07                      61.03                 29.60
# 340                    87.74                      84.80                 60.34
#
#      ...  reprobacion  reprobacion_transicion  reprobacion_primaria  \
# 51   ...         6.48                    6.99                 91.96
# 73   ...         7.78                    1.66                 91.87
# 276  ...          NaN                    2.28                 89.34
# 340  ...         6.86                    2.02                 94.15
#
#      reprobacion_secundaria  reprobacion_media  repitencia  \
# 51                     9.45               4.55        6.98
# 73                    12.57               6.50        7.55
# 276                   10.89               5.65       10.59
# 340                   11.47               5.39        8.00
#
#      repitencia_transicion  repitencia_primaria  repitencia_secundaria  \
# 51                    6.99                 7.92                   7.45
# 73                    1.66                 7.11                  10.98
# 276                   2.28                12.95                  11.33
# 340                   2.02                 6.72                  12.10
#
#      repitencia_media
# 51               2.27
# 73               3.20
# 276              3.19
# 340              4.05
#
# [4 rows x 37 columns]
# Rows with boolean indexing: 4
# Rows with query(): 4

# %% [markdown]
# ---
#
# ## Bonus: Design Your Own Filter (if time permits)
#
# Think of a question you could ask about the education data. Write the filter to answer it.
#
# Example questions:
# - Which departments had improving dropout rates (2022 lower than 2020)?
# - Which departments in the Llanos region (Arauca, Casanare, Meta, Vichada) have the best coverage?
# - What was the range of approval rates in 2024?

# %%
# YOUR QUESTION: ________________________________
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Summary
#
# In this exercise you practiced:
#
# 1. **Single conditions** - `==`, `!=`, `>`, `<`, `>=`, `<=`
# 2. **Combining conditions** - `&` (AND), `|` (OR), `~` (NOT)
# 3. **Convenience methods** - `.isin()`, `.between()`, `.str.contains()`
# 4. **Clean syntax** - `.query()` as an alternative
#
# Key rules:
# - Use `&` `|` `~` (NOT `and` `or` `not`) for DataFrames
# - Always wrap conditions in **parentheses**
# - Add `na=False` to `.str.contains()`
#
# **Next:** Complete the workshop notebook for more complex filtering scenarios and analysis.
