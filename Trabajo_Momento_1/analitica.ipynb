# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
# ## Calidad de Datos Abiertos en Colombia
#
# Estudiante: Juan David Arboleda Molina
# Curso: Analítica de Datos
#
# Este proyecto realiza un análisis exploratorio del dataset
# "Reporte de Calidad de Datos Abiertos 2025" con el objetivo
# de identificar patrones, calidad de los datos y distribución
# de los datasets publicados en el portal de datos abiertos de Colombia.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# Se importan las librerías necesarias para el análisis:
#
# - pandas: manipulación de datos
# - numpy: operaciones numéricas
# - matplotlib: visualización
# - seaborn: gráficos estadísticos

# %%
df = pd.read_csv("Vista_Reporte_de_Calidad_de_Datos_Abiertos_2025_20260315.csv")
df.head()
# Out:
#                                               Título Tipo de activo  \
# 0  PLAN ANUAL DE ADQUISICIONES ALCALDÍA MUNICIPIO...        dataset
# 1          Administrativos Universidad del Magdalena        dataset
# 2  Evaluación de tierras con fines agrícolas para...        dataset
# 3  Informacion_clasificada_y_reservada_Notaria_Pr...        dataset
# 4            ACTIVIDADES DE EMPRENDIMIENTO EN MADRID        dataset
#
#                                 Suministró los datos  \
# 0    Alcaldía Municipal de La Unión, Valle Del Cauca
# 1                          Universidad del Magdalena
# 2  Unidad de Planificación Rural Agropecuaria - UPRA
# 3            Notaría Primera del Círculo de Envigado
# 4                 Secretaria de Desarrollo economico
#
#                         Categoría  \
# 0                 Función pública
# 1                       Educación
# 2  Agricultura y Desarrollo Rural
# 3                 Función pública
# 4   Comercio, Industria y Turismo
#
# ...

# %%
df.shape
# Out:
# (19175, 16)

# %% [markdown]
# Se carga el dataset utilizando pandas para analizar su estructura
# y visualizar las primeras filas del conjunto de datos.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19175 entries, 0 to 19174
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Título                      19175 non-null  str
#  1   Tipo de activo              19175 non-null  str
#  2   Suministró los datos        16615 non-null  str
#  3   Categoría                   17731 non-null  str
#  4   Descripción                 16878 non-null  str
#  5   Etapa de publicación        19175 non-null  str
#  6   Municipio                   18963 non-null  str
#  7   Nombre entidad              18963 non-null  str
#  8   Orden                       18963 non-null  str
#  9   Departamento                18963 non-null  str
#  10  Frequencia actualización    18963 non-null  str
#  11  Fecha de creación           19175 non-null  str
#  12  Fecha de publicación        18753 non-null  str
#  13  Fecha última actualización  19175 non-null  str
# ...

# %% [markdown]
# Este paso permite conocer:
#
# - número de registros
# - tipos de datos
# - valores nulos

# %%
df.describe()
# Out:
#        CALIFICACIÓN FINAL CALIDAD  NIVEL SELLO EXCELENCIA
# count                19175.000000            19175.000000
# mean                     7.955029                0.185554
# std                      0.922667                0.389962
# min                      0.850000                0.000000
# 25%                      7.490000                0.000000
# 50%                      8.000000                0.000000
# 75%                      8.520000                0.000000
# max                      9.890000                2.000000

# %% [markdown]
# Se calculan estadísticas descriptivas del dataset como:
#
# - media
# - desviación estándar
# - valores mínimos y máximos
# - percentiles

# %% [markdown]
# Revisión de datos nulos

# %%
df.isnull().sum()
# Out:
# Título                           0
# Tipo de activo                   0
# Suministró los datos          2560
# Categoría                     1444
# Descripción                   2297
# Etapa de publicación             0
# Municipio                      212
# Nombre entidad                 212
# Orden                          212
# Departamento                   212
# Frequencia actualización       212
# Fecha de creación                0
# Fecha de publicación           422
# Fecha última actualización       0
# CALIFICACIÓN FINAL CALIDAD       0
# NIVEL SELLO EXCELENCIA           0
# dtype: int64

# %% [markdown]
# Se identifican valores faltantes para determinar si es necesario:
#
# - eliminarlos
# - imputarlos
# - reemplazarlos

# %%
df["Suministró los datos"].fillna("No reportado", inplace=True)
df["Categoría"].fillna("No reportado", inplace=True)
df["Descripción"].fillna("No disponible", inplace=True)
df["Municipio"].fillna("No especificado", inplace=True)
# Out:
# /tmp/ipykernel_10752/2943159137.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Suministró los datos"].fillna("No reportado", inplace=True)
# /tmp/ipykernel_10752/2943159137.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...
